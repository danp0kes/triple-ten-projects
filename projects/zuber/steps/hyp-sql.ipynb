# %% [markdown]
# Retrieve the identifiers of the O'Hare and Loop neighborhoods  from the neighborhoods table.

# %% [markdown]
# ```SQL
# SELECT
#     name,
#     neighborhood_id
# FROM
#     neighborhoods
# WHERE
#     name LIKE '%Hare'
#     OR name LIKE 'Loop';
# ```
#
# Output:

# %% [markdown]
# |   name  | neighborhood_id |
# |---------|-----------------|
# |  Loop   |       50        |
# | O'Hare  |       63        |

# %% [markdown]
# For each hour, retrieve the weather condition records from the weather_records table. Using the CASE operator, break all hours into two groups: Bad if the description field contains the words rain or storm, and Good for others. Name the resulting field weather_conditions. The final table must include two fields: date and hour (ts) and weather_conditions.

# %% [markdown]
# ```sql
# SELECT
#     DATE_TRUNC('hour', ts) AS date_hour,
#     CASE
#         WHEN LOWER(description) LIKE '%rain%' OR LOWER(description) LIKE '%storm%' THEN 'Bad'
#         ELSE 'Good'
#     END AS weather_conditions
# FROM
#     weather_records
# ORDER BY
#     date_hour;
# ```

# %% [markdown]
# Output:

# %% [markdown]
# |    date_hour     | weather_conditions |
# |------------------|--------------------|
# | 2017-11-01 00:00 |        Good        |
# | 2017-11-01 01:00 |        Good        |
# | 2017-11-01 02:00 |        Good        |
# | 2017-11-01 03:00 |        Good        |
# | 2017-11-01 04:00 |        Good        |
# | 2017-11-01 05:00 |        Good        |
# | 2017-11-01 06:00 |        Good        |
# | 2017-11-01 07:00 |        Good        |
# | 2017-11-01 08:00 |        Good        |
# | 2017-11-01 09:00 |        Good        |
# | 2017-11-01 10:00 |        Good        |
# | 2017-11-01 11:00 |        Good        |
# | 2017-11-01 12:00 |        Good        |
# | 2017-11-01 13:00 |        Good        |
# | 2017-11-01 14:00 |        Good        |
# | 2017-11-01 15:00 |        Good        |
# | 2017-11-01 16:00 |        Good        |
# | 2017-11-01 17:00 |        Good        |
# | 2017-11-01 18:00 |        Good        |
# | 2017-11-01 19:00 |        Good        |
# | 2017-11-01 20:00 |        Good        |
# | 2017-11-01 21:00 |        Good        |
# | 2017-11-01 22:00 |        Good        |
# | 2017-11-01 23:00 |        Good        |
# | 2017-11-02 00:00 |        Good        |
# | 2017-11-02 01:00 |        Good        |
# | 2017-11-02 02:00 |        Good        |
# | 2017-11-02 03:00 |         Bad        |
# | 2017-11-02 04:00 |         Bad        |
# | 2017-11-02 05:00 |         Bad        |
# | 2017-11-02 06:00 |         Bad        |
# | 2017-11-02 07:00 |         Bad        |
# | 2017-11-02 08:00 |        Good        |
# | 2017-11-02 09:00 |        Good        |
# | 2017-11-02 10:00 |        Good        |
# | 2017-11-02 11:00 |        Good        |
# | 2017-11-02 12:00 |         Bad        |
# | 2017-11-02 13:00 |        Good        |
# | 2017-11-02 14:00 |        Good        |
# | 2017-11-02 15:00 |        Good        |
# | 2017-11-02 16:00 |        Good        |
# | 2017-11-02 17:00 |        Good        |
# | 2017-11-02 18:00 |        Good        |
# | 2017-11-02 19:00 |        Good        |
# | 2017-11-02 20:00 |         Bad        |
# | 2017-11-02 21:00 |         Bad        |
# | 2017-11-02 22:00 |        Good        |
# | 2017-11-02 23:00 |        Good        |
# | 2017-11-03 00:00 |         Bad        |
# | 2017-11-03 01:00 |        Good        |
# | 2017-11-03 02:00 |        Good        |
# | 2017-11-03 03:00 |        Good        |
# | 2017-11-03 04:00 |        Good        |
# | 2017-11-03 05:00 |        Good        |
# | 2017-11-03 06:00 |        Good        |
# | 2017-11-03 07:00 |        Good        |
# | 2017-11-03 08:00 |        Good        |
# | 2017-11-03 09:00 |        Good        |
# | 2017-11-03 10:00 |        Good        |
# | 2017-11-03 11:00 |        Good        |
# | 2017-11-03 12:00 |        Good        |
# | 2017-11-03 13:00 |        Good        |
# | 2017-11-03 14:00 |        Good        |
# | 2017-11-03 15:00 |        Good        |
# | 2017-11-03 16:00 |        Good        |
# | 2017-11-03 17:00 |        Good        |
# | 2017-11-03 18:00 |        Good        |
# | 2017-11-03 19:00 |        Good        |
# | 2017-11-03 20:00 |        Good        |
# | 2017-11-03 21:00 |        Good        |
# | 2017-11-03 22:00 |        Good        |
# | 2017-11-03 23:00 |        Good        |
# | 2017-11-04 00:00 |        Good        |
# | 2017-11-04 01:00 |        Good        |
# | 2017-11-04 02:00 |        Good        |
# | 2017-11-04 03:00 |        Good        |
# | 2017-11-04 04:00 |        Good        |
# | 2017-11-04 05:00 |        Good        |
# | 2017-11-04 06:00 |        Good        |
# | 2017-11-04 07:00 |        Good        |
# | 2017-11-04 08:00 |        Good        |
# | 2017-11-04 09:00 |        Good        |
# | 2017-11-04 10:00 |        Good        |
# | 2017-11-04 11:00 |        Good        |

# %% [markdown]
# Retrieve from the trips table all the rides that started in the Loop (pickup_location_id: 50) on a Saturday and ended at O'Hare (dropoff_location_id: 63). Get the weather conditions for each ride. Use the method you applied in the previous task. Also, retrieve the duration of each ride. Ignore rides for which data on weather conditions is not available.
#
# The table columns should be in the following order:
#
# start_ts
# weather_conditions
# duration_seconds
# Sort by trip_id.

# %% [markdown]
# Output:

# %% [markdown]
# | start_ts           | weather_conditions | duration_seconds |
# |---------------------|---------------------|-------------------|
# | 2017-11-25 12:00:00 | Good                | 1380             |
# | 2017-11-25 16:00:00 | Good                | 2410             |
# | 2017-11-25 14:00:00 | Good                | 1920             |
# | 2017-11-25 12:00:00 | Good                | 1543             |
# | 2017-11-04 10:00:00 | Good                | 2512             |
# | 2017-11-11 07:00:00 | Good                | 1440             |
# | 2017-11-11 04:00:00 | Good                | 1320             |
# | 2017-11-04 16:00:00 | Bad                 | 2969             |
# | 2017-11-18 11:00:00 | Good                | 2280             |
# | 2017-11-04 16:00:00 | Bad                 | 3120             |
# | 2017-11-11 15:00:00 | Good                | 4800             |
